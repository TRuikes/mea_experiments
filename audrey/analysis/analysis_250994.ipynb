# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
current_dir = Path().resolve()
sys.path.append(current_dir.parent.parent.as_posix())

# %% General setup
import pandas as pd
from pathlib import Path
from audrey.data_io import DataIO

import utils
import numpy as np
from utils import make_figure, save_fig
from scipy.stats import wilcoxon
from axorus.preprocessing.project_colors import ProjectColors


# Load data
session_id = '250904_A'
data_dir = Path(r'C:\audrey')
figure_dir = Path(r'C:\audrey\Figure') / '250904_A'

data_io = DataIO(data_dir)
loadname = data_dir / f'{session_id}_cells.csv'
data_io.load_session(session_id, load_pickle=True, load_waveforms=False)
data_io.dump_as_pickle()
cells_df = pd.read_csv(loadname, header=[0, 1], index_col=0)
clrs = ProjectColors()

INCLUDE_RANGE = 50  # include cells at max distance = 50 um

clrs = ProjectColors()
# Out:
# Loading pickled data (not from h5 file)

# %%
# %% Detect electrode stim site with most significant responses, per cell

electrodes = data_io.burst_df.electrode.unique()

pref_ec_dict = {}

for cluster_id in data_io.cluster_df.index.values:

    pref_ec = None
    n_sig_pref_ec = None

    max_fr = None
    for ec in electrodes:
        df = data_io.burst_df.query(f'electrode == {ec}')
        tids = df.train_id.unique()
        n_sig = 0
        for tid in tids:
            if cells_df.loc[cluster_id, (tid, 'is_significant')] is True:
                n_sig += 1

        if n_sig > 1:
            if pref_ec is None or n_sig > n_sig_pref_ec:
                pref_ec = ec
                n_sig_pref_ec = n_sig

    pref_ec_dict[cluster_id] = pref_ec

# %%
# Print available recordings in data
print("Available recordings in data:")
for r in data_io.burst_df.recording_name.unique():
    print(f"- {r}")
# Out:
# Available recordings in data:
# - 250904_A_005_noblocker_PA_prr-series
# - 250904_A_006_noblocker_PA_prr-series
# - 250904_A_007_noblocker_DMD_light-series20ms
# - 250904_A_008_noblocker_DMD_light-series200ms
# - 250904_A_009_noblocker_PADMD_light-prr-series

# %%
#%% Plot raster plots for each individual cell

cluster_ids = data_io.cluster_df.index.values

# Select which recordings to plot
recording_names = [
    '250904_A_005_noblocker_PA_prr-series',
    '250904_A_006_noblocker_PA_prr-series',
    '250904_A_007_noblocker_DMD_light-series20ms',
    '250904_A_008_noblocker_DMD_light-series200ms',
    '250904_A_009_noblocker_PADMD_light-prr-series',
]

for cluster_id in cluster_ids:

    cluster_data = utils.load_obj(data_dir / 'bootstrapped' / f'bootstrap_{cluster_id}.pkl')

    n_electrodes = electrodes.size

    electrode = pref_ec_dict[cluster_id]

    if electrode is None: # Skip cells without pref electrode
        continue

    # Setup figure layout
    fig = utils.make_figure(width=1, height=1.5,
        x_domains={1: [[0.1, 0.9]],},
        y_domains={1: [[0.1, 0.9]]},
    )

    # Setup variables for plotting
    burst_offset = 0
    x_plot, y_plot = [], []
    yticks = []
    ytext = []
    pos = dict(row=1, col=1)


    for rec_i, rec_name in enumerate(recording_names):
        d_select = data_io.burst_df.query('electrode == electrode and '
                                              'recording_name == @rec_name').copy()
        d_select.sort_values('duty_cycle', inplace=True)
        # repetition_frequencies = d_select.repetition_frequency.unique()

        if '_005_' in rec_name:
            stim_strenghtes = d_select.duty_cycle.unique()
        elif '_006_' in rec_name:
            stim_strenghtes = d_select.duty_cycle.unique()
        elif '_007_' in rec_name:
            stim_strenghtes = d_select.light_intensity.unique()
        elif '_008_' in rec_name:
            stim_strenghtes = d_select.light_intensity.unique()
        elif '_009_' in rec_name:
            stim_strenghtes = d_select.laser_duty_cycle.unique()

        for stim_strenght in stim_strenghtes:
            if '_005_' in rec_name or '_006_' in rec_name:
                tid = d_select.query('duty_cycle == @stim_strenght').iloc[0].train_id
                bd = data_io.burst_df.query('train_id == @tid').iloc[0].burst_duration
                rname = 'PA'

            elif '_007_' in rec_name or '_008_' in rec_name:
                tid = d_select.query('light_intensity == @stim_strenght').iloc[0].train_id
                bd = np.nan
                rname = 'DMD'

            elif '_009_' in rec_name:
                tid = d_select.query('laser_duty_cycle == @stim_strenght').iloc[0].train_id
                bd = data_io.burst_df.query('train_id == @tid').iloc[0].laser_burst_duration
                rname = 'PA+DMD'
        
            spike_times = cluster_data[tid]['spike_times']
            bins = cluster_data[tid]['bins']

            ytext.append(f'stimval: {stim_strenght:.0f} bd: {bd:.0f}, {rname}')
            yticks.append(burst_offset + len(spike_times) / 2)

            for burst_i, sp in enumerate(spike_times):
                x_plot.append(np.vstack([sp, sp, np.full(sp.size, np.nan)]).T.flatten())
                y_plot.append(np.vstack([np.ones(sp.size) * burst_offset,
                                         np.ones(sp.size)* burst_offset +1, np.full(sp.size, np.nan)]).T.flatten())
                burst_offset += 1

    x_plot = np.hstack(x_plot)
    y_plot = np.hstack(y_plot)

    fig.add_scatter(
        x=x_plot, y=y_plot,
        mode='lines', line=dict(color='black', width=0.5),
        showlegend=False,
        **pos,
    )

    fig.update_xaxes(
        tickvals=np.arange(-500, 500, 100),
        title_text=f'time [ms]',
        range=[bins[0]-1, bins[-1]+1],
        **pos,
    )

    fig.update_yaxes(
        # range=[0, n_bursts],
        tickvals=yticks,
        ticktext=ytext,
        **pos,
    )

    sname = figure_dir  / 'raster plots' / f'{cluster_id}'

    utils.save_fig(fig, sname, display=False)
# Out:
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_000.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_001.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_002.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_003.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_004.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_005.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_006.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_007.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_008.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_009.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_010.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_011.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_012.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_013.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_014.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_015.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_016.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_017.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_018.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_019.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_020.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_021.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_022.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_023.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_024.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_025.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_026.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_027.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_028.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_029.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_030.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_031.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_032.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_033.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_034.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_035.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_036.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_037.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_038.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_039.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_040.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_041.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_042.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_043.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_044.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_045.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_046.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_047.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_048.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_049.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_050.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_051.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_052.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_053.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_054.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_055.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_056.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_057.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_058.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_059.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_060.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_061.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_062.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_063.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_064.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_065.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_066.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_067.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_068.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_069.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_070.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_071.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_072.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_074.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_075.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_076.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_077.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_078.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_080.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_081.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_082.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_083.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_084.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_085.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_086.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_087.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_088.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_089.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_090.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_091.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_092.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_093.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_094.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_095.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_096.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_097.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_098.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_099.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_100.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_101.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_102.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_103.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_104.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_105.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_106.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_107.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_108.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_109.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_110.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_111.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_112.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_113.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_114.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_115.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_116.png
# saved: C:\audrey\Figure\250904_A\raster plots\uid_250904_117.png

# %%
# Plot single cell response curves
# 1 plot per recording with response curves per condition

# Setup figure spacing
x_offset = 0.05
x_spacing = 0.1


cluster_ids = data_io.cluster_df.index.values

# Select which recordings to plot
recording_names = [
    '250904_A_005_noblocker_PA_prr-series',
    '250904_A_006_noblocker_PA_prr-series',
    '250904_A_007_noblocker_DMD_light-series20ms',
    '250904_A_008_noblocker_DMD_light-series200ms',
    '250904_A_009_noblocker_PADMD_light-prr-series',
]

plot_titles = [
    'PA',
    'PA',
    'DMD - 20ms',
    'DMD - 200ms',
    'PA+DMD',  
]


# cluster_ids = ['uid_250904_015']
for cluster_id in cluster_ids:

    # Get preferred electrode
    electrode = pref_ec_dict[cluster_id]
    if electrode is None: # Skip cells without pref electrode
        continue


    # Setup figure layout
    fig = utils.simple_fig(width=1, height=1.5, n_cols=3, n_rows=2,
        subplot_titles={
            1: [plot_titles[0], plot_titles[1], plot_titles[2]], 
            2: [plot_titles[3], plot_titles[4], '']}
    )

    # Setup variables for plotting
    burst_offset = 0
    x_plot, y_plot = [], []
    yticks = []
    ytext = []
    pos = dict(row=1, col=1)
    plot_row = 1
    plot_col = 1

    # Load cluster data
    cluster_data = utils.load_obj(data_dir / 'bootstrapped' / f'bootstrap_{cluster_id}.pkl')

    for rec_i, rec_name in enumerate(recording_names):
        y_max = 0
        d_select = data_io.burst_df.query('electrode == electrode and '
                                              'recording_name == @rec_name').copy()
        d_select.sort_values('duty_cycle', inplace=True)
        # repetition_frequencies = d_select.repetition_frequency.unique()

        if '_005_' in rec_name:
            stim_strenghts = d_select.duty_cycle.unique()
        elif '_006_' in rec_name:
            stim_strenghts = d_select.duty_cycle.unique()
        elif '_007_' in rec_name:
            stim_strenghts = d_select.light_intensity.unique()
        elif '_008_' in rec_name:
            stim_strenghts = d_select.light_intensity.unique()
        elif '_009_' in rec_name:
            stim_strenghts = d_select.laser_duty_cycle.unique()

        for stim_strenght in stim_strenghts:
            if '_005_' in rec_name or '_006_' in rec_name:
                tid = d_select.query('duty_cycle == @stim_strenght').iloc[0].train_id
                clr_a = clrs.duty_cycle(stim_strenght, 0.2)
                clr = clrs.duty_cycle(stim_strenght)
                bd = d_select.query('duty_cycle == @stim_strenght').iloc[0].laser_burst_duration

            elif '_007_' in rec_name or '_008_' in rec_name:
                tid = d_select.query('light_intensity == @stim_strenght').iloc[0].train_id
                clr_a = clrs.dmd_light_stim(stim_strenght, 0.2)
                clr = clrs.dmd_light_stim(stim_strenght)
                bd = d_select.query('light_intensity == @stim_strenght').iloc[0].dmd_burst_duration

            elif '_009_' in rec_name:
                tid = d_select.query('laser_duty_cycle == @stim_strenght').iloc[0].train_id
                clr_a = clrs.padmd_stim(stim_strenght, 0.2)
                clr = clrs.padmd_stim(stim_strenght)
                bd = d_select.query('laser_duty_cycle == @stim_strenght').iloc[0].laser_burst_duration

        
            bins = cluster_data[tid]['bins']
            sp = cluster_data[tid]['firing_rate']
            ci_low = cluster_data[tid]['firing_rate_ci_low']
            ci_high = cluster_data[tid]['firing_rate_ci_high']

            
            if sp is None:
                continue

            if ci_high.max() > y_max:
                y_max = ci_high.max()

            pos = dict(row=plot_row, col=plot_col )

            fig.add_scatter(x=[0, 0, bd, bd],
                            y=[0, 1000, 1000, 0],
                            line=dict(width=0),
                            mode='lines',
                            fillcolor='rgba(128, 128, 128, 0.1)',
                            fill='toself',
                            showlegend=False,
                            **pos,)

            fig.add_scatter(
                x=bins, y=ci_low, line=dict(width=0), showlegend=False,
                **pos,
            )

            fig.add_scatter(
                x=bins,
                y=ci_high,
                line=dict(width=0),
                mode='lines',
                fill='tonexty',
                fillcolor=clr_a,  # shaded area
                showlegend=False, **pos,
            )

            fig.add_scatter(
                x=bins, y=sp, line=dict(width=1, color=clr), name='Firing rate', **pos,
                showlegend=False,
            )

            fig.update_xaxes(
                tickvals=np.arange(-500, 500, 100),
                title_text=f'time [ms]',
                range=[-101, 351],
                **pos,
            )

            fig.update_yaxes(
                range=[0, y_max],
                tickvals=yticks,
                ticktext=ytext,
                **pos,
            )

        plot_col += 1
        if plot_col > 3:
            plot_col = 1
            plot_row += 1



    sname = figure_dir  / 'firing_rate_per_condition' / f'{cluster_id}'

    utils.save_fig(fig, sname, display=False, formats=['png', 'svg'])
# Out:
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_000.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_000.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_001.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_001.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_002.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_002.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_003.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_003.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_004.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_004.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_005.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_005.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_006.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_006.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_007.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_007.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_008.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_008.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_009.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_009.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_010.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_010.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_011.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_011.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_012.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_012.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_013.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_013.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_014.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_014.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_015.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_015.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_016.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_016.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_017.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_017.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_018.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_018.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_019.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_019.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_020.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_020.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_021.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_021.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_022.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_022.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_023.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_023.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_024.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_024.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_025.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_025.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_026.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_026.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_027.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_027.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_028.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_028.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_029.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_029.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_030.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_030.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_031.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_031.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_032.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_032.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_033.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_033.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_034.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_034.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_035.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_035.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_036.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_036.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_037.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_037.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_038.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_038.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_039.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_039.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_040.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_040.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_041.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_041.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_042.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_042.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_043.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_043.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_044.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_044.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_045.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_045.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_046.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_046.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_047.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_047.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_048.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_048.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_049.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_049.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_050.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_050.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_051.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_051.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_052.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_052.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_053.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_053.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_054.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_054.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_055.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_055.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_056.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_056.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_057.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_057.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_058.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_058.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_059.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_059.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_060.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_060.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_061.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_061.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_062.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_062.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_063.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_063.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_064.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_064.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_065.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_065.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_066.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_066.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_067.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_067.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_068.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_068.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_069.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_069.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_070.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_070.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_071.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_071.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_072.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_072.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_074.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_074.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_075.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_075.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_076.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_076.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_077.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_077.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_078.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_078.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_080.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_080.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_081.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_081.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_082.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_082.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_083.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_083.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_084.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_084.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_085.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_085.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_086.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_086.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_087.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_087.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_088.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_088.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_089.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_089.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_090.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_090.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_091.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_091.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_092.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_092.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_093.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_093.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_094.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_094.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_095.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_095.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_096.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_096.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_097.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_097.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_098.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_098.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_099.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_099.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_100.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_100.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_101.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_101.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_102.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_102.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_103.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_103.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_104.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_104.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_105.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_105.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_106.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_106.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_107.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_107.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_108.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_108.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_109.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_109.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_110.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_110.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_111.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_111.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_112.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_112.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_113.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_113.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_114.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_114.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_115.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_115.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_116.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_116.svg
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_117.png
# saved: C:\audrey\Figure\250904_A\firing_rate_per_condition\uid_250904_117.svg

# %%
# Plot single cell response curves
# Plot the strongest stim condition for 1 PA, 1 DMD and 1 PADMD session

# Setup figure spacing
x_offset = 0.05
x_spacing = 0.1


cluster_ids = data_io.cluster_df.index.values

# Select which recordings to plot
recording_names = [
    '250904_A_005_noblocker_PA_prr-series',
    '250904_A_008_noblocker_DMD_light-series200ms',
    '250904_A_009_noblocker_PADMD_light-prr-series',
]



# cluster_ids = ['uid_250904_015']
for cluster_id in cluster_ids:

    # Get preferred electrode
    electrode = pref_ec_dict[cluster_id]
    if electrode is None: # Skip cells without pref electrode
        continue


    # Setup figure layout
    fig = utils.make_figure(width=0.8, height=0.8,
        x_domains={1: [[0.1, 0.9]],},
        y_domains={1: [[0.1, 0.9]]},
    )


    # Setup variables for plotting
    burst_offset = 0
    x_plot, y_plot = [], []
    yticks = []
    ytext = []

    # Load cluster data
    cluster_data = utils.load_obj(data_dir / 'bootstrapped' / f'bootstrap_{cluster_id}.pkl')

    y_max = 0

    for rec_i, rec_name in enumerate(recording_names):
        d_select = data_io.burst_df.query('electrode == electrode and '
                                              'recording_name == @rec_name').copy()
        d_select.sort_values('duty_cycle', inplace=True)
        # repetition_frequencies = d_select.repetition_frequency.unique()


        if '_005_' in rec_name or '_006_' in rec_name:
            stim_strenght = d_select.duty_cycle.unique().max()
            tid = d_select.query('duty_cycle == @stim_strenght').iloc[0].train_id
            clr_a = clrs.duty_cycle(stim_strenght, 0.2)
            clr = clrs.duty_cycle(stim_strenght)
            bd = d_select.query('duty_cycle == @stim_strenght').iloc[0].laser_burst_duration

        elif '_007_' in rec_name or '_008_' in rec_name:
            stim_strenght = d_select.light_intensity.unique().max()
            tid = d_select.query('light_intensity == @stim_strenght').iloc[0].train_id
            clr_a = clrs.dmd_light_stim(stim_strenght, 0.2)
            clr = clrs.dmd_light_stim(stim_strenght)
            bd = d_select.query('light_intensity == @stim_strenght').iloc[0].dmd_burst_duration

        elif '_009_' in rec_name:
            stim_strenght = d_select.laser_duty_cycle.unique().max()
            tid = d_select.query('laser_duty_cycle == @stim_strenght').iloc[0].train_id
            clr_a = clrs.padmd_stim(stim_strenght, 0.2)
            clr = clrs.padmd_stim(stim_strenght)
            bd = d_select.query('laser_duty_cycle == @stim_strenght').iloc[0].laser_burst_duration

    
        bins = cluster_data[tid]['bins']
        sp = cluster_data[tid]['firing_rate']
        ci_low = cluster_data[tid]['firing_rate_ci_low']
        ci_high = cluster_data[tid]['firing_rate_ci_high']

            
        if sp is None:
            continue

        if ci_high.max() > y_max:
            y_max = ci_high.max()

        fig.add_scatter(
            x=[0, 0],
            y=[0, 1000],
            line=dict(width=2, color='red'),
            mode='lines',
            showlegend=False,
        )

        # fig.add_scatter(x=[0, 0, bd, bd],
        #                 y=[0, 1000, 1000, 0],
        #                 line=dict(width=0),
        #                 mode='lines',
        #                 fillcolor='rgba(128, 128, 128, 0.1)',
        #                 fill='toself',
        #                 showlegend=False,
        #                 )

        fig.add_scatter(
            x=bins, y=ci_low, line=dict(width=0), showlegend=False,
        )

        fig.add_scatter(
            x=bins,
            y=ci_high,
            line=dict(width=0),
            mode='lines',
            fill='tonexty',
            fillcolor=clr_a,  # shaded area
            showlegend=False,
        )

        fig.add_scatter(
            x=bins, y=sp, line=dict(width=1, color=clr), name='Firing rate',
            showlegend=False,
        )

        fig.update_xaxes(
            tickvals=np.arange(-500, 500, 100),
            title_text=f'time [ms]',
            range=[-51, 151],
        )

        fig.update_yaxes(
            range=[0, y_max],
            tickvals=yticks,
            ticktext=ytext,
        )


    sname = figure_dir  / 'condition_comparison' / f'{cluster_id}'

    utils.save_fig(fig, sname, display=False, formats=['png', 'svg'])
# Out:
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_000.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_000.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_001.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_001.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_002.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_002.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_003.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_003.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_004.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_004.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_005.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_005.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_006.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_006.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_007.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_007.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_008.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_008.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_009.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_009.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_010.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_010.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_011.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_011.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_012.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_012.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_013.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_013.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_014.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_014.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_015.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_015.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_016.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_016.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_017.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_017.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_018.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_018.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_019.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_019.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_020.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_020.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_021.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_021.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_022.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_022.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_023.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_023.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_024.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_024.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_025.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_025.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_026.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_026.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_027.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_027.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_028.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_028.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_029.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_029.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_030.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_030.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_031.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_031.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_032.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_032.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_033.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_033.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_034.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_034.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_035.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_035.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_036.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_036.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_037.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_037.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_038.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_038.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_039.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_039.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_040.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_040.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_041.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_041.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_042.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_042.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_043.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_043.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_044.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_044.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_045.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_045.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_046.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_046.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_047.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_047.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_048.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_048.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_049.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_049.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_050.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_050.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_051.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_051.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_052.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_052.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_053.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_053.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_054.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_054.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_055.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_055.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_056.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_056.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_057.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_057.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_058.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_058.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_059.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_059.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_060.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_060.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_061.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_061.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_062.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_062.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_063.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_063.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_064.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_064.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_065.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_065.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_066.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_066.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_067.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_067.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_068.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_068.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_069.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_069.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_070.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_070.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_071.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_071.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_072.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_072.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_074.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_074.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_075.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_075.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_076.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_076.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_077.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_077.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_078.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_078.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_080.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_080.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_081.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_081.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_082.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_082.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_083.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_083.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_084.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_084.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_085.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_085.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_086.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_086.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_087.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_087.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_088.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_088.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_089.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_089.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_090.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_090.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_091.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_091.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_092.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_092.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_093.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_093.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_094.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_094.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_095.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_095.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_096.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_096.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_097.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_097.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_098.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_098.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_099.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_099.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_100.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_100.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_101.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_101.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_102.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_102.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_103.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_103.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_104.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_104.svg
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_105.png
# saved: C:\audrey\Figure\250904_A\condition_comparison\uid_250904_105.svg
