# %%
import pickle
import numpy as np

dmp_file = r'C:\thijs\sono_data\2026-07-08 rat LE 3322 Mekano6 B\processed\figures\triggers\dmp.pkl'
with open(dmp_file, 'rb') as f:
    dmp = pickle.load(f)

# %%
import pickle
